# %% [markdown]
# #Description:
# In this notebook, we will explore LSTM models' accuracy in one-step-ahead (daily) weather forecast
#
# #Part 1: Data Preparation

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
#Reading data from Google Drive
#This dataset is private, so I cannot share
weather = pd.read_csv("Masters\Master_Hsinchu copy.csv", on_bad_lines='skip')
weather = weather[["Date", "Hour", "AirTemperature", "DewPointTemperature", "Precipitation", "PrecipitationDuration", "RelativeHumidity", "SeaLevelPressure", "StationPressure", "WindSpeed", "WindDirection"]]

# %%
weather = weather.rename(columns={'AirTemperature': 'temperature', 'Date': 'date'})
weather['date'] = pd.to_datetime(weather['date'])
weather.set_index('date')
weather.head(5)
# Out:
#         date  Hour  temperature  DewPointTemperature  Precipitation  \
# 0 2015-01-01     1         15.5                  8.7            0.0
# 1 2015-01-01     2         15.0                  8.4            0.0
# 2 2015-01-01     3         14.6                  8.2            0.0
# 3 2015-01-01     4         13.9                  7.9            0.0
# 4 2015-01-01     5         13.5                  8.1            0.0
#
#    PrecipitationDuration  RelativeHumidity  SeaLevelPressure  StationPressure  \
# 0                    0.0                64            1023.1           1019.6
# 1                    0.0                65            1023.8           1020.3
# 2                    0.0                65            1024.2           1020.7
# 3                    0.0                67            1024.4           1020.9
# 4                    0.0                70            1024.9           1021.4
#
#   WindSpeed WindDirection
# 0       4.0            40
# 1       3.8            40
# 2       3.5            20
# 3       3.2            20
# 4       4.4            30

# %% [markdown]
# Data description:
#
# * date: YYYY-MM-DD
#
# * temperature: average temperature in Istanbul at the given date, in degrees Celcius
#
# * tempmax: maximum temperature in Istanbul at the given date, in degrees Celcius
#
# * tempmin: minimum temperature in Istanbul at the given date, in degrees Celcius
#
# * dew: dew point; required temperatuer to have dew in the air
#
# * humidity: average humiditiy in Istanbul at the given date, as percentage
#
# * precip: precipitation, in mm
#
# * preciptype: type of precipitation, such as rain, snow
#
# * windspeed: average windspeed in kilometers per hour
#
# * winddir: direction of the wind, 360$^\circ$
#
# * cloudcover: percentage of sky covered in cloud, daily average
#
# Will be filling NA values of cloudcover with 0, NA values in precipitation type with None, and one-hot-encode precipitation type & month

# %%
# weather['preciptype'] =  weather['preciptype'].fillna('None')
# weather['cloudcover'] =  weather['cloudcover'].fillna(0)
# weather.isna().sum()

# %% [markdown]
# There are only a few other NA values, deleting these rows will result negligible data loss.

# %%
weather.dropna(inplace=True)
weather.info
# Out:
# <bound method DataFrame.info of             date  Hour  temperature  DewPointTemperature  Precipitation  \
# 0     2015-01-01     1         15.5                  8.7            0.0
# 1     2015-01-01     2         15.0                  8.4            0.0
# 2     2015-01-01     3         14.6                  8.2            0.0
# 3     2015-01-01     4         13.9                  7.9            0.0
# 4     2015-01-01     5         13.5                  8.1            0.0
# ...          ...   ...          ...                  ...            ...
# 90547 2025-04-30    20         25.1                 20.6            0.0
# 90548 2025-04-30    21         24.8                 20.7            0.0
# 90549 2025-04-30    22         23.9                 20.6            0.0
# 90550 2025-04-30    23         23.6                 20.7            0.0
# 90551 2025-04-30    24         23.3                 20.8            0.0
#
#        PrecipitationDuration  RelativeHumidity  SeaLevelPressure  \
# 0                        0.0                64            1023.1
# 1                        0.0                65            1023.8
# 2                        0.0                65            1024.2
# 3                        0.0                67            1024.4
# 4                        0.0                70            1024.9
# ...                      ...               ...               ...
# 90547                    0.0                76            1012.3
# 90548                    0.0                78            1012.7
# 90549                    0.0                82            1012.8
# 90550                    0.0                84            1012.8
# 90551                    0.0                86            1012.8
#
#        StationPressure WindSpeed WindDirection
# 0               1019.6       4.0            40
# 1               1020.3       3.8            40
# 2               1020.7       3.5            20
# 3               1020.9       3.2            20
# 4               1021.4       4.4            30
# ...                ...       ...           ...
# 90547           1009.0       0.1             0
# 90548           1009.3       0.3            70
# 90549           1009.4       0.6            60
# 90550           1009.4       0.2             0
# 90551           1009.4       0.3            80
#
# [90552 rows x 11 columns]>

# %%
weather['month'] = weather['date'].dt.month

# %%
weather.head(2)
# Out:
#         date  Hour  temperature  DewPointTemperature  Precipitation  \
# 0 2015-01-01     1         15.5                  8.7            0.0
# 1 2015-01-01     2         15.0                  8.4            0.0
#
#    PrecipitationDuration  RelativeHumidity  SeaLevelPressure  StationPressure  \
# 0                    0.0                64            1023.1           1019.6
# 1                    0.0                65            1023.8           1020.3
#
#   WindSpeed WindDirection  month
# 0       4.0            40      1
# 1       3.8            40      1

# %% [markdown]
# Our main dataframe will be "weather". Let's examine the data even more:

# %%
weather_seperated = weather[['date', 'month', 'temperature']].copy(deep=True)
weather_seperated['year'] = weather['date'].dt.year
weather_seperated.drop(['date'], axis=1, inplace=True)
weather_seperated = weather_seperated.pivot_table(index='month',  columns='year', values='temperature')
weather_seperated.head(2)
# Out:
# year        2015       2016       2017       2018       2019       2020  \
# month
# 1      16.003763  15.572984  17.703898  16.329570  17.717070  16.742473
# 2      16.184077  14.482902  16.249702  14.624256  18.027381  17.570833
#
# year        2021       2022       2023       2024       2025
# month
# 1      15.286962  16.859946  16.318817  16.163038  15.695699
# 2      17.870387  15.661310  16.291220  17.226868  15.796280

# %%
weather_seperated.plot()
plt.ylabel('Temperature (degrees Celcius)')
plt.title("Monthly Temperature Averages, Each Line Represents a Year")
plt.legend().remove()
plt.show()

# %%
weather_seperated = weather[['date', 'month', 'Precipitation']].copy(deep=True)
weather_seperated['year'] = weather['date'].dt.year
weather_seperated.drop(['date'], axis=1, inplace=True)
weather_seperated = weather_seperated.pivot_table(index='month',  columns='year', values='Precipitation')
weather_seperated.head(2)
# Out:
# year       2015      2016      2017      2018      2019      2020      2021  \
# month
# 1      0.030511  0.418145  0.031452  0.358468  0.034274  0.048387  0.006048
# 2      0.070238  0.105316  0.136458  0.124256  0.101042  0.079023  0.076637
#
# year       2022      2023      2024      2025
# month
# 1      0.096774  0.012769  0.028898  0.035618
# 2      0.316964  0.031994  0.073994  0.086310

# %%
weather_seperated.plot()
plt.ylabel('Precipitation')
plt.title("Monthly Precipitation Averages, Each Line Represents a Year")
plt.legend().remove()
plt.show()

# %%
weather_seperated = weather[['date', 'month', 'WindSpeed']].copy(deep=True)
weather_seperated['year'] = weather['date'].dt.year
weather_seperated.drop(['date'], axis=1, inplace=True)
# Convert WindSpeed to numeric, coercing errors to NaN, then drop rows with NaN
weather_seperated['WindSpeed'] = pd.to_numeric(weather_seperated['WindSpeed'], errors='coerce')
weather_seperated = weather_seperated.dropna(subset=['WindSpeed'])

weather_seperated = weather_seperated.pivot_table(index='month', columns='year', values='WindSpeed')
weather_seperated.head(2)
# Out:
# year       2015      2016      2017      2018      2019      2020      2021  \
# month
# 1      2.405242  2.043683  2.195161  2.154839  2.039919  1.603898  2.265188
# 2      1.772024  2.378448  2.300893  2.099107  1.631548  1.781178  1.824405
#
# year       2022      2023      2024      2025
# month
# 1      2.210215  2.288441  2.002957  2.235484
# 2      2.383780  2.491815  1.842529  2.088690

# %%
weather_seperated.plot()
plt.ylabel('WindSpeed')
plt.title("Monthly WindSpeed Averages, Each Line Represents a Year")
plt.legend().remove()
plt.show()

# %% [markdown]
# From the chart, we can see monthly temperature averages follow a meaningful seasonal trend.
#
# Note: legend is removed as there are 32 years

# %%
# g = sns.PairGrid(weather[['temperature', 'Precipitation', 'RelativeHumidity', 'WindSpeed']])
g = sns.PairGrid(weather[["temperature", "DewPointTemperature", "Precipitation", "RelativeHumidity", "SeaLevelPressure", "StationPressure", "WindSpeed", "WindDirection"]])
g.map(sns.scatterplot)

# %% [markdown]
# #Part 2: Checking the Naive prediction's error
#
# A naive temperature prediction would be "tomorrow's average temperature will be the same with today". We will check the error term when we use this prediction and use it as the benchmark of our LSTM model.

# %%
weather_naive = weather[['date', 'temperature']].copy(deep=True)
weather_naive['prev_temperature'] = weather_naive['temperature'].shift(1)
weather_naive.drop([0], inplace=True)
weather_naive['difference'] = weather_naive['temperature'] - weather_naive['prev_temperature']
weather_naive['square_error'] = weather_naive['difference'] ** 2
weather_naive.head(2)
# Out:
#         date  temperature  prev_temperature  difference  square_error
# 1 2015-01-01         15.0              15.5        -0.5          0.25
# 2 2015-01-01         14.6              15.0        -0.4          0.16

# %%
square_error = weather_naive['square_error'].mean()
print(f'Square Error of the Naive Approach to Temperature is {square_error:.3f}')
# Out:
# Square Error of the Naive Approach to Temperature is 0.575

# %%
weather_naive = weather[['date', 'Precipitation']].copy(deep=True)
weather_naive['prev_Precipitatione'] = weather_naive['Precipitation'].shift(1)
weather_naive.drop([0], inplace=True)
weather_naive['difference'] = weather_naive['Precipitation'] - weather_naive['Precipitation']
weather_naive['square_error'] = weather_naive['difference'] ** 2
weather_naive.head(2)
# Out:
#         date  Precipitation  prev_Precipitatione  difference  square_error
# 1 2015-01-01            0.0                  0.0         0.0           0.0
# 2 2015-01-01            0.0                  0.0         0.0           0.0

# %%
square_error = weather_naive['square_error'].mean()
print(f'Square Error of the Naive Approach to Precipitation is {square_error:.3f}')
# Out:
# Square Error of the Naive Approach to Precipitation is 0.000

# %% [markdown]
# #Part 3: LSTM model for Weather Prediction

# %%
weather.head(2)
# Out:
#         date  Hour  temperature  DewPointTemperature  Precipitation  \
# 0 2015-01-01     1         15.5                  8.7            0.0
# 1 2015-01-01     2         15.0                  8.4            0.0
#
#    PrecipitationDuration  RelativeHumidity  SeaLevelPressure  StationPressure  \
# 0                    0.0                64            1023.1           1019.6
# 1                    0.0                65            1023.8           1020.3
#
#   WindSpeed WindDirection  month
# 0       4.0            40      1
# 1       3.8            40      1

# %%
#One-hot-encoding precipitation type and month
weather_LSTM = weather.copy(deep=True)
weather_LSTM = pd.get_dummies(weather, columns = ['month'])
weather_LSTM.columns
# Out:
# Index(['date', 'Hour', 'temperature', 'DewPointTemperature', 'Precipitation',
#        'PrecipitationDuration', 'RelativeHumidity', 'SeaLevelPressure',
#        'StationPressure', 'WindSpeed', 'WindDirection', 'month_1', 'month_2',
#        'month_3', 'month_4', 'month_5', 'month_6', 'month_7', 'month_8',
#        'month_9', 'month_10', 'month_11', 'month_12'],
#       dtype='object')

# %%
weather_LSTM.head(2)
# Out:
#         date  Hour  temperature  DewPointTemperature  Precipitation  \
# 0 2015-01-01     1         15.5                  8.7            0.0
# 1 2015-01-01     2         15.0                  8.4            0.0
#
#    PrecipitationDuration  RelativeHumidity  SeaLevelPressure  StationPressure  \
# 0                    0.0                64            1023.1           1019.6
# 1                    0.0                65            1023.8           1020.3
#
#   WindSpeed  ... month_3  month_4  month_5  month_6  month_7  month_8  \
# 0       4.0  ...   False    False    False    False    False    False
# 1       3.8  ...   False    False    False    False    False    False
#
#    month_9  month_10  month_11  month_12
# 0    False     False     False     False
# 1    False     False     False     False
#
# [2 rows x 23 columns]

# %%
input_data = weather_LSTM.drop(['date'], axis=1)

input_data = input_data.apply(pd.to_numeric, errors='coerce')
input_data = input_data.dropna()

targets = weather_LSTM['Precipitation'].values

# %% [markdown]
# We need to decide how many days' prior we need to see to predict today. Trial and error is a valid approach, but for this example I will be using 20 days as the target is not to get the best answer, just to check if LSTM is getting better predictions than the naive approach.

# %%
T = 20                    #Number of timesteps to look while predicting
D = input_data.shape[1]   #Dimensionality of the input
N = len(input_data) - T
print(f'Dimensions are {T} × {D} × {N}')
# Out:
# Dimensions are 20 × 22 × 90143

# %%
#Train size: 80% of the total data size
train_size = int(len(input_data) * 0.90)

# Normalization of the inputs
scaler = StandardScaler()
scaler.fit(input_data[:train_size + T - 1])
input_data = scaler.transform(input_data)

# %% [markdown]
# We need to create the train set and the test set and convert from numpy to torch.

# %%
# Preparing X_train and y_train
X_train = np.zeros((train_size, T, D))
y_train = np.zeros((train_size, 1))

for t in range(train_size):
  X_train[t, :, :] = input_data[t:t+T]
  y_train[t] = (targets[t+T])

# %%
# Preparing X_test and y_test
X_test = np.zeros((N - train_size, T, D))
y_test = np.zeros((N - train_size, 1))

for i in range(N - train_size):
  t = i + train_size
  X_test[i, :, :] = input_data[t:t+T]
  y_test[i] = (targets[t+T])

# %%
# Make inputs and targets
X_train = torch.from_numpy(X_train.astype(np.float32))
y_train = torch.from_numpy(y_train.astype(np.float32))
X_test = torch.from_numpy(X_test.astype(np.float32))
y_test = torch.from_numpy(y_test.astype(np.float32))

# %% [markdown]
# Using a classical LSTM structure

# %%
class LSTM(nn.Module):
  def __init__(self, input_dim, hidden_dim, layer_dim, output_dim):
    super(LSTM, self).__init__()
    self.M = hidden_dim
    self.L = layer_dim

    self.rnn = nn.LSTM(
        input_size=input_dim,
        hidden_size=hidden_dim,
        num_layers=layer_dim,
        batch_first=True)
    #batch_first to have (batch_dim, seq_dim, feature_dim)
    self.fc = nn.Linear(hidden_dim, output_dim)

  def forward(self, X):
    # initial hidden state and cell state
    h0 = torch.zeros(self.L, X.size(0), self.M).to(device)
    c0 = torch.zeros(self.L, X.size(0), self.M).to(device)

    out, (hn, cn) = self.rnn(X, (h0.detach(), c0.detach()))

    # h(T) at the final time step
    out = self.fc(out[:, -1, :])
    return out

# %% [markdown]
# For the number of hidden layers, the recommendation is 1 for simple problems and 2 for complex features. As our time series is slightly complex, I will be using 2.
#
# Considering our training data size of 10,000 and input dimensionality; it's better to use hidden size at least 100 and at most 1000. 512 yielded good result.

# %%
model = LSTM(D, 512, 2, 1)
model.to(device)
# Out:
# LSTM(
#   (rnn): LSTM(22, 512, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
# )

# %% [markdown]
# At training, Adam optimizer failed to converge for a long time (started to converge at around 800th epoch). SGD with 0.9 momentum worked well.

# %%
from torch.utils.data import DataLoader, TensorDataset

BATCH_SIZE = 128  # Adjust as needed for your GPU

train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# Training
def train(model, learning_rate, train_loader, test_loader, epochs=200):
    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=1e-4)

    train_losses = np.zeros(epochs)
    test_losses = np.zeros(epochs)

    for epoch in range(epochs):
        model.train()
        batch_losses = []
        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device)
            optimizer.zero_grad()
            outputs = model(xb)
            loss = criterion(outputs, yb)
            loss.backward()
            optimizer.step()
            batch_losses.append(loss.item())
        train_losses[epoch] = np.mean(batch_losses)

        # Test loss
        model.eval()
        with torch.no_grad():
            test_batch_losses = []
            for xb, yb in test_loader:
                xb = xb.to(device)
                yb = yb.to(device)
                outputs = model(xb)
                loss = criterion(outputs, yb)
                test_batch_losses.append(loss.item())
            test_losses[epoch] = np.mean(test_batch_losses)

        if (epoch + 1) % 50 == 0:
            print(f'At epoch {epoch+1} of {epochs}, Train Loss: {train_losses[epoch]:.3f}, Test Loss: {test_losses[epoch]:.3f}')

    return train_losses, test_losses

# %%
# move data to GPU
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
train_losses, test_losses = train(model,
                                  0.01,
                                  train_loader,
                                  test_loader,
                                  epochs=350)
# Out:
# At epoch 50 of 350, Train Loss: 1.749, Test Loss: 1.571
# At epoch 100 of 350, Train Loss: 1.358, Test Loss: 1.836
# At epoch 150 of 350, Train Loss: 1.041, Test Loss: 1.756
# At epoch 200 of 350, Train Loss: 0.800, Test Loss: 1.744
# At epoch 250 of 350, Train Loss: 0.359, Test Loss: 1.764
# At epoch 300 of 350, Train Loss: 0.074, Test Loss: 1.763
# At epoch 350 of 350, Train Loss: 0.057, Test Loss: 1.867

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.xlabel('epoch no')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# We don't see an overfitting pattern. It's possible to train the model a little more as we haven't started to see the seperation of train loss - test loss in a meaningful manner, but the gains will be minimal.

# %%
#Checking one-step prediction performance of the model
test_target = y_test.cpu().detach().numpy()
test_predictions = []

for i in range(len(test_target)):
  input_ = X_test[i].reshape(1, T, D)
  p = model(input_)[0,0].item()

  # update the predictions list
  test_predictions.append(p)

# %%
plot_len = len(test_predictions)
plot_df = weather[['date', 'Precipitation']].copy(deep=True)
plot_df = plot_df.iloc[-plot_len:]
plot_df['prediction'] = test_predictions
plot_df.set_index('date', inplace=True)
plot_df.head(5)
# Out:
#             Precipitation  prediction
# date
# 2024-04-21            0.0    0.020473
# 2024-04-21            0.0   -0.077147
# 2024-04-21            0.0   -0.051601
# 2024-04-21            0.0   -0.065487
# 2024-04-21            0.0    0.010996

# %%
plt.plot(plot_df['Precipitation'], label='Actual Precipitation', linewidth=1)
plt.plot(plot_df['prediction'], label='One-step Prediction', linewidth=1)
plt.xlabel('date')
plt.ylabel('Precipitation')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We are seeing a good fit. However, it seems the model is not good at predicting rapid increase/decrease in temperature in a short-period of time (a few days).

# %%
LTSM_error = pd.DataFrame(test_target, columns = ['targets'])
LTSM_error['predictions'] =test_predictions
LTSM_error['error'] = LTSM_error['targets'] - LTSM_error['predictions']
LTSM_error['error_square'] = LTSM_error['error'] ** 2
err = LTSM_error['error_square'].mean()
print(f'Mean square error is: {err:.3f}')
# Out:
# Mean square error is: 1.836

# %%
plt.hist(LTSM_error['error'], bins=25)
plt.xlabel('Temperature Difference (real - predictied)')
plt.ylabel('count')
plt.title('Distribution of Differences')
plt.tight_layout()

# %% [markdown]
# #Discussion:
#
# The LSTM model is better in predicting one-step-ahead average weather in degrees celcius, in compare to the naive model. The naive model's error was 3.54, LSTM reduced it to 2.56.
#
# This model is not fine-tuned, so I believe further reduction in square error is possible. However, considering we only use data from Istanbul's previous weather (20-day) and weather prediction is complex, I believe it is not possible to reduce square error below 2.0.

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# Print additional evaluation metrics for the model

# Convert predictions and targets to numpy arrays if needed
y_true = test_target.flatten()
y_pred = np.array(test_predictions)

# Mean Absolute Error
mae = mean_absolute_error(y_true, y_pred)
print(f"Mean Absolute Error (MAE): {mae:.3f}")

# R^2 Score
r2 = r2_score(y_true, y_pred)
print(f"R^2 Score: {r2:.3f}")

# Print a few actual vs predicted values for inspection
print("\nSample predictions (actual vs predicted):")
for actual, pred in zip(y_true[:1000], y_pred[:1000]):
    print(f"Actual: {actual:.3f}, Predicted: {pred:.3f}")
# Out:
# Mean Absolute Error (MAE): 0.279
# R^2 Score: -0.179
#
# Sample predictions (actual vs predicted):
# Actual: 0.000, Predicted: 0.020
# Actual: 0.000, Predicted: -0.077
# Actual: 0.000, Predicted: -0.052
# Actual: 0.000, Predicted: -0.065
# Actual: 0.000, Predicted: 0.011
# Actual: 0.000, Predicted: 0.040
# Actual: 0.000, Predicted: 0.040
# Actual: 0.000, Predicted: 0.040
# Actual: 0.000, Predicted: 0.018
# Actual: 0.000, Predicted: -0.028
# Actual: 0.000, Predicted: -0.074
# Actual: 0.000, Predicted: -0.070
# Actual: 0.000, Predicted: 0.006
# Actual: 0.000, Predicted: -0.028
# Actual: 0.000, Predicted: -0.028
# Actual: 0.000, Predicted: -0.049
# Actual: 0.000, Predicted: 0.030
# Actual: 0.000, Predicted: 0.150
# Actual: 0.000, Predicted: -0.145
# Actual: 0.000, Predicted: 0.069
# Actual: 0.000, Predicted: 0.092
# Actual: 0.000, Predicted: -0.082
# Actual: 0.000, Predicted: 0.005
# Actual: 0.000, Predicted: -0.085
# Actual: 0.000, Predicted: -0.011
# Actual: 0.000, Predicted: 0.056
# Actual: 0.000, Predicted: 0.109
# Actual: 0.000, Predicted: 0.146
# Actual: 0.000, Predicted: 0.117
# Actual: 0.000, Predicted: 0.019
# Actual: 0.500, Predicted: -0.029
# Actual: 0.000, Predicted: -0.055
# Actual: 0.000, Predicted: 0.051
# Actual: 0.000, Predicted: -0.109
# Actual: 0.000, Predicted: -0.010
# Actual: 0.000, Predicted: -0.090
# Actual: 0.000, Predicted: -0.074
# Actual: 0.000, Predicted: -0.022
# Actual: 0.000, Predicted: 0.064
# Actual: 0.000, Predicted: 0.107
# Actual: 0.000, Predicted: 0.165
# Actual: 0.000, Predicted: 0.213
# Actual: 0.500, Predicted: 0.123
# Actual: 0.500, Predicted: -0.048
# Actual: 0.500, Predicted: -0.082
# Actual: 0.000, Predicted: -0.106
# Actual: 0.000, Predicted: -0.172
# Actual: 0.000, Predicted: -0.017
# Actual: 0.000, Predicted: -0.022
# Actual: 0.000, Predicted: -0.066
# Actual: 0.000, Predicted: 0.061
# Actual: 0.000, Predicted: -0.010
# Actual: 0.000, Predicted: 0.077
# Actual: 1.000, Predicted: 0.069
# Actual: 1.000, Predicted: 0.023
# Actual: 3.500, Predicted: 0.060
# Actual: 0.000, Predicted: 0.045
# Actual: 0.500, Predicted: 0.011
# Actual: 0.000, Predicted: 0.003
# Actual: 0.000, Predicted: 0.043
# Actual: 0.000, Predicted: -0.023
# Actual: 0.000, Predicted: -0.058
# Actual: 0.000, Predicted: -0.009
# Actual: 0.000, Predicted: 0.056
# Actual: 0.000, Predicted: 0.764
# Actual: 0.000, Predicted: 0.037
# Actual: 0.000, Predicted: -0.021
# Actual: 0.000, Predicted: 0.060
# Actual: 0.000, Predicted: 0.035
# Actual: 0.000, Predicted: -0.036
# Actual: 0.000, Predicted: 0.087
# Actual: 0.000, Predicted: 0.197
# Actual: 0.000, Predicted: 0.114
# Actual: 1.000, Predicted: 0.070
# Actual: 1.000, Predicted: 0.123
# Actual: 0.500, Predicted: 0.170
# Actual: 0.500, Predicted: 0.111
# Actual: 0.000, Predicted: 0.150
# Actual: 0.000, Predicted: 0.157
# Actual: 0.000, Predicted: 0.138
# Actual: 1.500, Predicted: 0.042
# Actual: 1.000, Predicted: 0.091
# Actual: 0.000, Predicted: 0.080
# Actual: 1.500, Predicted: 0.048
# Actual: 0.000, Predicted: -0.039
# Actual: 3.500, Predicted: -0.082
# Actual: 0.000, Predicted: -0.111
# Actual: 0.000, Predicted: -0.093
# Actual: 0.000, Predicted: -0.093
# Actual: 0.000, Predicted: -0.090
# Actual: 0.000, Predicted: -0.149
# Actual: 0.000, Predicted: 0.015
# Actual: 0.000, Predicted: 6.162
# Actual: 0.000, Predicted: 4.474
# Actual: 0.000, Predicted: -0.254
# Actual: 0.000, Predicted: 0.105
# Actual: 0.500, Predicted: 1.470
# Actual: 0.000, Predicted: 2.704
# Actual: 0.000, Predicted: 0.693
# Actual: 0.000, Predicted: 0.321
# Actual: 0.000, Predicted: 0.007
# Actual: 0.000, Predicted: 0.026
# Actual: 0.000, Predicted: 0.026
# Actual: 0.000, Predicted: -0.187
# Actual: 0.000, Predicted: 0.294
# Actual: 0.000, Predicted: -0.130
# Actual: 0.000, Predicted: -0.168
# Actual: 0.000, Predicted: -0.188
# Actual: 0.000, Predicted: 0.055
# Actual: 0.000, Predicted: 0.253
# Actual: 0.000, Predicted: 0.178
# Actual: 0.000, Predicted: 0.717
# Actual: 0.000, Predicted: -0.227
# Actual: 0.000, Predicted: -0.137
# Actual: 0.000, Predicted: 0.671
# Actual: 0.000, Predicted: 0.746
# Actual: 0.000, Predicted: 0.185
# Actual: 0.000, Predicted: 0.160
# Actual: 0.000, Predicted: 0.212
# Actual: 0.000, Predicted: 0.045
# Actual: 0.000, Predicted: 0.012
# Actual: 0.000, Predicted: 0.031
# Actual: 0.000, Predicted: 0.076
# Actual: 0.000, Predicted: 0.081
# Actual: 0.000, Predicted: 0.064
# Actual: 0.000, Predicted: 0.062
# Actual: 0.000, Predicted: 0.054
# Actual: 0.000, Predicted: 0.053
# Actual: 0.000, Predicted: -0.046
# Actual: 0.000, Predicted: -0.114
# Actual: 0.000, Predicted: -0.094
# Actual: 0.000, Predicted: -0.045
# Actual: 0.000, Predicted: -0.023
# Actual: 0.000, Predicted: 0.001
# Actual: 0.000, Predicted: -0.005
# Actual: 0.000, Predicted: 0.017
# Actual: 0.000, Predicted: 0.037
# Actual: 0.000, Predicted: -0.007
# Actual: 0.000, Predicted: -0.048
# Actual: 0.000, Predicted: -0.045
# Actual: 0.000, Predicted: -0.024
# Actual: 0.000, Predicted: 0.081
# Actual: 0.000, Predicted: 0.815
# Actual: 0.000, Predicted: 1.885
# Actual: 0.000, Predicted: 0.071
# Actual: 0.000, Predicted: 0.182
# Actual: 0.000, Predicted: -0.017
# Actual: 0.000, Predicted: -0.126
# Actual: 0.000, Predicted: -0.139
# Actual: 0.000, Predicted: -0.121
# Actual: 0.000, Predicted: -0.355
# Actual: 0.000, Predicted: -0.200
# Actual: 0.000, Predicted: -0.225
# Actual: 0.000, Predicted: -0.356
# Actual: 0.000, Predicted: -0.162
# Actual: 0.000, Predicted: 0.085
# Actual: 0.000, Predicted: 0.024
# Actual: 0.000, Predicted: -0.003
# Actual: 0.000, Predicted: -0.033
# Actual: 0.000, Predicted: 0.026
# Actual: 0.000, Predicted: 0.109
# Actual: 0.000, Predicted: 0.095
# Actual: 0.000, Predicted: 0.140
# Actual: 0.000, Predicted: -0.029
# Actual: 0.000, Predicted: -0.057
# Actual: 0.000, Predicted: -0.209
# Actual: 0.000, Predicted: -0.013
# Actual: 0.000, Predicted: 0.314
# Actual: 0.000, Predicted: 0.086
# Actual: 0.000, Predicted: 0.023
# Actual: 0.000, Predicted: 0.435
# Actual: 0.000, Predicted: 0.118
# Actual: 0.000, Predicted: 0.075
# Actual: 0.000, Predicted: -0.012
# Actual: 0.000, Predicted: 0.020
# Actual: 0.000, Predicted: 0.025
# Actual: 0.000, Predicted: -0.018
# Actual: 0.000, Predicted: 0.024
# Actual: 0.000, Predicted: -0.005
# Actual: 0.000, Predicted: -0.006
# Actual: 0.000, Predicted: -0.011
# Actual: 0.000, Predicted: -0.018
# Actual: 0.000, Predicted: -0.026
# Actual: 0.000, Predicted: 0.003
# Actual: 0.000, Predicted: -0.063
# Actual: 0.000, Predicted: -0.036
# Actual: 0.000, Predicted: -0.016
# Actual: 0.000, Predicted: -0.318
# Actual: 0.000, Predicted: -0.422
# Actual: 0.000, Predicted: -0.212
# Actual: 0.000, Predicted: -0.136
# Actual: 0.000, Predicted: 0.107
# Actual: 0.000, Predicted: -0.181
# Actual: 0.000, Predicted: -0.067
# Actual: 0.000, Predicted: 0.013
# Actual: 0.000, Predicted: 0.290
# Actual: 0.000, Predicted: 0.258
# Actual: 0.000, Predicted: 0.077
# Actual: 0.000, Predicted: -0.090
# Actual: 0.000, Predicted: 0.274
# Actual: 0.000, Predicted: 0.206
# Actual: 0.000, Predicted: 0.078
# Actual: 0.000, Predicted: 0.099
# Actual: 0.000, Predicted: 0.269
# Actual: 0.000, Predicted: 0.116
# Actual: 0.000, Predicted: 0.531
# Actual: 0.000, Predicted: 0.424
# Actual: 0.000, Predicted: 0.542
# Actual: 0.000, Predicted: 0.185
# Actual: 0.000, Predicted: 1.068
# Actual: 0.000, Predicted: 0.714
# Actual: 0.000, Predicted: -0.161
# Actual: 0.000, Predicted: 0.114
# Actual: 0.000, Predicted: 0.124
# Actual: 0.000, Predicted: -0.306
# Actual: 0.000, Predicted: 0.047
# Actual: 0.000, Predicted: 0.065
# Actual: 0.000, Predicted: 0.055
# Actual: 0.000, Predicted: 0.022
# Actual: 0.000, Predicted: 0.026
# Actual: 0.000, Predicted: 0.031
# Actual: 0.000, Predicted: 0.130
# Actual: 0.000, Predicted: 0.082
# Actual: 0.000, Predicted: 0.028
# Actual: 0.000, Predicted: 0.017
# Actual: 0.000, Predicted: 0.015
# Actual: 0.000, Predicted: 0.066
# Actual: 0.000, Predicted: 0.048
# Actual: 0.000, Predicted: -0.013
# Actual: 0.000, Predicted: 0.028
# Actual: 0.000, Predicted: 0.062
# Actual: 0.000, Predicted: 0.101
# Actual: 0.000, Predicted: -0.061
# Actual: 0.000, Predicted: -0.054
# Actual: 0.000, Predicted: 0.087
# Actual: 0.000, Predicted: 0.134
# Actual: 0.000, Predicted: 0.056
# Actual: 0.000, Predicted: -0.007
# Actual: 0.000, Predicted: 0.401
# Actual: 0.000, Predicted: 0.130
# Actual: 0.000, Predicted: 0.035
# Actual: 0.000, Predicted: 0.053
# Actual: 0.000, Predicted: 0.115
# Actual: 0.000, Predicted: 0.093
# Actual: 0.000, Predicted: 0.060
# Actual: 0.000, Predicted: -0.010
# Actual: 0.000, Predicted: -0.061
# Actual: 0.000, Predicted: -0.136
# Actual: 0.000, Predicted: -0.079
# Actual: 0.000, Predicted: 0.125
# Actual: 0.000, Predicted: 0.080
# Actual: 0.000, Predicted: 0.054
# Actual: 0.000, Predicted: 0.047
# Actual: 0.000, Predicted: 0.002
# Actual: 0.000, Predicted: -0.041
# Actual: 0.000, Predicted: 0.084
# Actual: 0.000, Predicted: 1.393
# Actual: 0.000, Predicted: 0.265
# Actual: 0.000, Predicted: -0.041
# Actual: 0.000, Predicted: -0.040
# Actual: 0.000, Predicted: -0.164
# Actual: 0.000, Predicted: 0.038
# Actual: 0.000, Predicted: 0.296
# Actual: 0.000, Predicted: 0.284
# Actual: 0.000, Predicted: 0.103
# Actual: 0.000, Predicted: -0.027
# Actual: 0.000, Predicted: -0.062
# Actual: 0.000, Predicted: 0.029
# Actual: 0.000, Predicted: 0.047
# Actual: 0.000, Predicted: 0.057
# Actual: 0.000, Predicted: 0.028
# Actual: 0.000, Predicted: -0.043
# Actual: 0.000, Predicted: -0.112
# Actual: 0.000, Predicted: 0.037
# Actual: 0.000, Predicted: 0.174
# Actual: 0.000, Predicted: 0.067
# Actual: 0.000, Predicted: -0.066
# Actual: 0.000, Predicted: -0.025
# Actual: 0.000, Predicted: 0.017
# Actual: 0.000, Predicted: 0.210
# Actual: 0.000, Predicted: 0.123
# Actual: 0.000, Predicted: 0.104
# Actual: 0.000, Predicted: 0.062
# Actual: 0.000, Predicted: 0.142
# Actual: 0.000, Predicted: 0.130
# Actual: 0.000, Predicted: 0.222
# Actual: 0.000, Predicted: 0.132
# Actual: 0.000, Predicted: 0.271
# Actual: 0.000, Predicted: 0.100
# Actual: 0.000, Predicted: 0.016
# Actual: 0.000, Predicted: -0.014
# Actual: 0.000, Predicted: 0.070
# Actual: 0.000, Predicted: 0.194
# Actual: 0.000, Predicted: 0.189
# Actual: 0.000, Predicted: 0.141
# Actual: 0.000, Predicted: 0.013
# Actual: 0.000, Predicted: 0.006
# Actual: 0.000, Predicted: 0.083
# Actual: 0.000, Predicted: 0.204
# Actual: 0.000, Predicted: 0.396
# Actual: 0.000, Predicted: 0.171
# Actual: 0.000, Predicted: 0.134
# Actual: 0.000, Predicted: 0.249
# Actual: 0.000, Predicted: 0.142
# Actual: 0.000, Predicted: 0.089
# Actual: 0.000, Predicted: 0.050
# Actual: 0.000, Predicted: 0.072
# Actual: 0.000, Predicted: 0.104
# Actual: 0.000, Predicted: 0.158
# Actual: 0.000, Predicted: 0.122
# Actual: 0.000, Predicted: 0.017
# Actual: 0.000, Predicted: 0.032
# Actual: 0.000, Predicted: -0.003
# Actual: 0.000, Predicted: -0.053
# Actual: 0.000, Predicted: -0.032
# Actual: 0.000, Predicted: -0.048
# Actual: 0.000, Predicted: -0.084
# Actual: 0.000, Predicted: -0.110
# Actual: 0.000, Predicted: -0.089
# Actual: 0.000, Predicted: 0.097
# Actual: 0.000, Predicted: -0.063
# Actual: 2.500, Predicted: -0.152
# Actual: 3.500, Predicted: -0.064
# Actual: 0.000, Predicted: 0.018
# Actual: 0.000, Predicted: -0.048
# Actual: 0.000, Predicted: -0.067
# Actual: 0.000, Predicted: -0.026
# Actual: 0.000, Predicted: -0.030
# Actual: 0.000, Predicted: 0.093
# Actual: 0.000, Predicted: 0.369
# Actual: 0.000, Predicted: 0.093
# Actual: 0.000, Predicted: -0.066
# Actual: 0.000, Predicted: 0.042
# Actual: 0.000, Predicted: -0.012
# Actual: 0.000, Predicted: -0.066
# Actual: 0.000, Predicted: 0.129
# Actual: 0.000, Predicted: 0.074
# Actual: 0.000, Predicted: 0.035
# Actual: 0.000, Predicted: -0.024
# Actual: 0.000, Predicted: -0.129
# Actual: 0.000, Predicted: -0.114
# Actual: 0.000, Predicted: -0.123
# Actual: 0.000, Predicted: -0.160
# Actual: 0.000, Predicted: -0.053
# Actual: 0.000, Predicted: -0.127
# Actual: 0.000, Predicted: -0.101
# Actual: 0.000, Predicted: -0.052
# Actual: 0.000, Predicted: -0.041
# Actual: 0.000, Predicted: -0.015
# Actual: 0.000, Predicted: -0.019
# Actual: 0.000, Predicted: -0.032
# Actual: 0.000, Predicted: 0.046
# Actual: 0.000, Predicted: -0.052
# Actual: 0.000, Predicted: -0.065
# Actual: 0.000, Predicted: -0.173
# Actual: 0.000, Predicted: 0.399
# Actual: 0.000, Predicted: -0.198
# Actual: 0.000, Predicted: 0.608
# Actual: 0.000, Predicted: 1.541
# Actual: 0.000, Predicted: 0.243
# Actual: 0.000, Predicted: 0.046
# Actual: 0.000, Predicted: -0.187
# Actual: 0.000, Predicted: 0.092
# Actual: 0.000, Predicted: 0.793
# Actual: 0.000, Predicted: 0.114
# Actual: 0.000, Predicted: -0.308
# Actual: 0.000, Predicted: -0.300
# Actual: 0.000, Predicted: 0.063
# Actual: 0.000, Predicted: -0.136
# Actual: 0.000, Predicted: -0.063
# Actual: 0.000, Predicted: 0.058
# Actual: 0.000, Predicted: -0.032
# Actual: 0.000, Predicted: -0.010
# Actual: 0.000, Predicted: 0.053
# Actual: 0.000, Predicted: 0.090
# Actual: 0.000, Predicted: 0.045
# Actual: 0.000, Predicted: 0.114
# Actual: 0.000, Predicted: -0.068
# Actual: 0.000, Predicted: -0.084
# Actual: 0.000, Predicted: -0.153
# Actual: 0.000, Predicted: -0.087
# Actual: 0.000, Predicted: -0.158
# Actual: 0.000, Predicted: 0.013
# Actual: 0.000, Predicted: -0.004
# Actual: 0.000, Predicted: 0.021
# Actual: 0.000, Predicted: 0.039
# Actual: 0.000, Predicted: -0.118
# Actual: 0.000, Predicted: -0.151
# Actual: 0.000, Predicted: -0.113
# Actual: 0.000, Predicted: 1.623
# Actual: 0.000, Predicted: 0.126
# Actual: 0.000, Predicted: -0.393
# Actual: 0.000, Predicted: 0.295
# Actual: 0.000, Predicted: -0.319
# Actual: 0.000, Predicted: -0.118
# Actual: 0.000, Predicted: 0.026
# Actual: 0.000, Predicted: 0.310
# Actual: 0.000, Predicted: 0.004
# Actual: 0.000, Predicted: -0.007
# Actual: 0.000, Predicted: -0.113
# Actual: 0.000, Predicted: -0.255
# Actual: 0.000, Predicted: 0.653
# Actual: 0.000, Predicted: 0.317
# Actual: 0.000, Predicted: -0.256
# Actual: 0.000, Predicted: -0.165
# Actual: 0.000, Predicted: 0.391
# Actual: 0.000, Predicted: 0.465
# Actual: 0.000, Predicted: -0.012
# Actual: 0.000, Predicted: 0.099
# Actual: 0.000, Predicted: 0.086
# Actual: 0.000, Predicted: -0.083
# Actual: 0.000, Predicted: -0.029
# Actual: 0.000, Predicted: -0.063
# Actual: 0.000, Predicted: -0.206
# Actual: 0.000, Predicted: -0.222
# Actual: 0.000, Predicted: -0.042
# Actual: 0.000, Predicted: 0.012
# Actual: 0.000, Predicted: -0.027
# Actual: 0.000, Predicted: -0.062
# Actual: 0.000, Predicted: 0.046
# Actual: 0.000, Predicted: 0.060
# Actual: 0.500, Predicted: -0.002
# Actual: 0.000, Predicted: 0.042
# Actual: 0.000, Predicted: 0.031
# Actual: 0.000, Predicted: 0.084
# Actual: 0.000, Predicted: 0.053
# Actual: 0.000, Predicted: 0.041
# Actual: 0.000, Predicted: -0.090
# Actual: 0.000, Predicted: 0.040
# Actual: 0.500, Predicted: 0.143
# Actual: 0.000, Predicted: 0.107
# Actual: 0.000, Predicted: 0.038
# Actual: 0.000, Predicted: 0.064
# Actual: 0.000, Predicted: 0.076
# Actual: 0.000, Predicted: 0.084
# Actual: 0.000, Predicted: 0.067
# Actual: 0.500, Predicted: 0.067
# Actual: 0.000, Predicted: -0.012
# Actual: 0.000, Predicted: -0.029
# Actual: 0.000, Predicted: -0.024
# Actual: 0.000, Predicted: 0.000
# Actual: 0.000, Predicted: 0.020
# Actual: 0.000, Predicted: 0.044
# Actual: 0.000, Predicted: -0.003
# Actual: 0.000, Predicted: -0.091
# Actual: 0.000, Predicted: -0.091
# Actual: 0.000, Predicted: 0.056
# Actual: 0.000, Predicted: 0.262
# Actual: 0.000, Predicted: 1.053
# Actual: 0.000, Predicted: 1.640
# Actual: 0.000, Predicted: 0.019
# Actual: 0.000, Predicted: -0.025
# Actual: 0.000, Predicted: 0.058
# Actual: 0.000, Predicted: -0.081
# Actual: 0.000, Predicted: -0.135
# Actual: 0.000, Predicted: -0.047
# Actual: 0.000, Predicted: -0.067
# Actual: 0.000, Predicted: -0.011
# Actual: 14.000, Predicted: -0.053
# Actual: 0.500, Predicted: -0.129
# Actual: 1.500, Predicted: -0.041
# Actual: 0.000, Predicted: -0.051
# Actual: 8.500, Predicted: -0.041
# Actual: 10.500, Predicted: 0.076
# Actual: 5.000, Predicted: 0.009
# Actual: 9.000, Predicted: -0.041
# Actual: 7.500, Predicted: -0.145
# Actual: 9.500, Predicted: -0.163
# Actual: 2.000, Predicted: -0.115
# Actual: 0.000, Predicted: -0.233
# Actual: 5.000, Predicted: -0.373
# Actual: 0.500, Predicted: -0.203
# Actual: 0.000, Predicted: -0.147
# Actual: 7.000, Predicted: -0.105
# Actual: 2.000, Predicted: -0.086
# Actual: 1.500, Predicted: -0.094
# Actual: 0.000, Predicted: -0.090
# Actual: 0.000, Predicted: -0.076
# Actual: 0.000, Predicted: -0.046
# Actual: 0.000, Predicted: -0.010
# Actual: 0.000, Predicted: -0.058
# Actual: 0.000, Predicted: -0.085
# Actual: 0.000, Predicted: -0.087
# Actual: 0.000, Predicted: -0.079
# Actual: 0.000, Predicted: -0.066
# Actual: 0.000, Predicted: -0.075
# Actual: 0.000, Predicted: -0.115
# Actual: 1.000, Predicted: -0.027
# Actual: 0.500, Predicted: -0.012
# Actual: 0.000, Predicted: 0.029
# Actual: 0.000, Predicted: 0.000
# Actual: 0.000, Predicted: 0.011
# Actual: 0.000, Predicted: 0.003
# Actual: 0.000, Predicted: 0.042
# Actual: 0.000, Predicted: -0.098
# Actual: 0.000, Predicted: -0.104
# Actual: 0.000, Predicted: -0.043
# Actual: 0.000, Predicted: -0.066
# Actual: 0.500, Predicted: 0.010
# Actual: 0.000, Predicted: -0.063
# Actual: 0.500, Predicted: -0.166
# Actual: 2.000, Predicted: -0.143
# Actual: 2.000, Predicted: -0.034
# Actual: 6.000, Predicted: -0.074
# Actual: 0.000, Predicted: -0.117
# Actual: 1.000, Predicted: -0.173
# Actual: 0.500, Predicted: -0.300
# Actual: 0.000, Predicted: -0.255
# Actual: 0.000, Predicted: -0.109
# Actual: 0.000, Predicted: -0.193
# Actual: 0.000, Predicted: -0.156
# Actual: 0.000, Predicted: -0.106
# Actual: 0.000, Predicted: -0.010
# Actual: 0.000, Predicted: -0.017
# Actual: 0.000, Predicted: -0.042
# Actual: 0.000, Predicted: -0.023
# Actual: 1.500, Predicted: 0.017
# Actual: 22.000, Predicted: -0.030
# Actual: 14.500, Predicted: -0.078
# Actual: 1.000, Predicted: 0.108
# Actual: 0.000, Predicted: -0.259
# Actual: 0.000, Predicted: -0.147
# Actual: 0.000, Predicted: -0.159
# Actual: 0.000, Predicted: -0.064
# Actual: 0.000, Predicted: -0.051
# Actual: 0.000, Predicted: -0.053
# Actual: 0.000, Predicted: -0.193
# Actual: 0.000, Predicted: -0.209
# Actual: 0.000, Predicted: -0.021
# Actual: 0.000, Predicted: -0.033
# Actual: 0.000, Predicted: 2.707
# Actual: 0.000, Predicted: 0.634
# Actual: 0.000, Predicted: -0.178
# Actual: 0.000, Predicted: 0.055
# Actual: 0.000, Predicted: 0.023
# Actual: 0.000, Predicted: -0.032
# Actual: 0.000, Predicted: 0.066
# Actual: 0.000, Predicted: 0.132
# Actual: 0.000, Predicted: 0.156
# Actual: 0.000, Predicted: -0.011
# Actual: 0.000, Predicted: 0.012
# Actual: 0.000, Predicted: 0.068
# Actual: 0.000, Predicted: 0.021
# Actual: 0.000, Predicted: -0.057
# Actual: 0.000, Predicted: -0.030
# Actual: 0.000, Predicted: 0.071
# Actual: 0.000, Predicted: 0.212
# Actual: 0.000, Predicted: 0.921
# Actual: 0.000, Predicted: 0.972
# Actual: 0.000, Predicted: 0.526
# Actual: 0.000, Predicted: 0.248
# Actual: 0.000, Predicted: 0.048
# Actual: 0.000, Predicted: -0.047
# Actual: 0.000, Predicted: 0.139
# Actual: 0.000, Predicted: 0.166
# Actual: 0.000, Predicted: 0.159
# Actual: 0.000, Predicted: 0.232
# Actual: 0.000, Predicted: 0.080
# Actual: 0.000, Predicted: -0.036
# Actual: 0.000, Predicted: 0.067
# Actual: 0.000, Predicted: 0.056
# Actual: 0.000, Predicted: 0.046
# Actual: 1.000, Predicted: 0.043
# Actual: 1.000, Predicted: 0.042
# Actual: 1.000, Predicted: 0.121
# Actual: 0.000, Predicted: 0.115
# Actual: 0.000, Predicted: 0.126
# Actual: 0.000, Predicted: 0.076
# Actual: 0.000, Predicted: 0.127
# Actual: 0.000, Predicted: 0.136
# Actual: 0.000, Predicted: 0.202
# Actual: 0.000, Predicted: 0.201
# Actual: 0.000, Predicted: 0.177
# Actual: 0.000, Predicted: 0.159
# Actual: 0.000, Predicted: 0.153
# Actual: 0.000, Predicted: 0.100
# Actual: 0.000, Predicted: 0.126
# Actual: 0.000, Predicted: 0.126
# Actual: 0.000, Predicted: 0.077
# Actual: 0.000, Predicted: 0.014
# Actual: 0.000, Predicted: 0.007
# Actual: 0.000, Predicted: 0.004
# Actual: 0.000, Predicted: -0.041
# Actual: 0.000, Predicted: 0.074
# Actual: 0.000, Predicted: 0.003
# Actual: 0.000, Predicted: -0.014
# Actual: 0.000, Predicted: -0.056
# Actual: 0.000, Predicted: -0.040
# Actual: 0.000, Predicted: -0.052
# Actual: 0.000, Predicted: -0.016
# Actual: 0.000, Predicted: 0.004
# Actual: 0.000, Predicted: -0.070
# Actual: 0.000, Predicted: -0.029
# Actual: 0.000, Predicted: 0.003
# Actual: 0.000, Predicted: 0.006
# Actual: 0.000, Predicted: 0.006
# Actual: 0.000, Predicted: 0.039
# Actual: 0.000, Predicted: 0.031
# Actual: 0.000, Predicted: 0.023
# Actual: 0.000, Predicted: 0.015
# Actual: 0.000, Predicted: 0.003
# Actual: 0.000, Predicted: -0.030
# Actual: 0.000, Predicted: -0.044
# Actual: 0.000, Predicted: -0.091
# Actual: 0.000, Predicted: -0.126
# Actual: 0.000, Predicted: -0.065
# Actual: 0.000, Predicted: -0.076
# Actual: 0.000, Predicted: 0.044
# Actual: 0.000, Predicted: -0.057
# Actual: 0.000, Predicted: -0.071
# Actual: 0.000, Predicted: 0.070
# Actual: 0.000, Predicted: 0.017
# Actual: 0.000, Predicted: -0.015
# Actual: 0.000, Predicted: 0.029
# Actual: 0.000, Predicted: -0.039
# Actual: 0.000, Predicted: -0.036
# Actual: 0.000, Predicted: -0.090
# Actual: 8.000, Predicted: -0.050
# Actual: 3.500, Predicted: -0.009
# Actual: 0.000, Predicted: 0.010
# Actual: 0.000, Predicted: -0.002
# Actual: 0.000, Predicted: -0.014
# Actual: 0.000, Predicted: -0.031
# Actual: 0.000, Predicted: -0.020
# Actual: 0.000, Predicted: 0.021
# Actual: 0.000, Predicted: 0.007
# Actual: 0.000, Predicted: -0.056
# Actual: 1.500, Predicted: -0.049
# Actual: 0.500, Predicted: -0.019
# Actual: 3.500, Predicted: 0.009
# Actual: 0.500, Predicted: -0.020
# Actual: 0.500, Predicted: -0.124
# Actual: 0.000, Predicted: -0.106
# Actual: 0.000, Predicted: -0.148
# Actual: 0.000, Predicted: -0.068
# Actual: 0.000, Predicted: -0.049
# Actual: 0.000, Predicted: -0.097
# Actual: 0.000, Predicted: -0.040
# Actual: 0.000, Predicted: 0.019
# Actual: 0.000, Predicted: 0.013
# Actual: 0.500, Predicted: -0.026
# Actual: 7.500, Predicted: -0.066
# Actual: 4.500, Predicted: -0.112
# Actual: 0.500, Predicted: -0.105
# Actual: 0.500, Predicted: -0.074
# Actual: 0.000, Predicted: -0.044
# Actual: 0.500, Predicted: -0.019
# Actual: 0.000, Predicted: -0.006
# Actual: 0.000, Predicted: -0.018
# Actual: 0.000, Predicted: -0.012
# Actual: 0.500, Predicted: 0.021
# Actual: 0.500, Predicted: -0.009
# Actual: 1.000, Predicted: -0.017
# Actual: 5.500, Predicted: 0.045
# Actual: 1.500, Predicted: -0.021
# Actual: 0.000, Predicted: -0.059
# Actual: 0.500, Predicted: -0.042
# Actual: 0.000, Predicted: 0.017
# Actual: 0.000, Predicted: -0.016
# Actual: 0.000, Predicted: -0.036
# Actual: 0.000, Predicted: 0.019
# Actual: 0.000, Predicted: 0.068
# Actual: 0.000, Predicted: 0.056
# Actual: 0.000, Predicted: 0.019
# Actual: 0.000, Predicted: 0.046
# Actual: 0.000, Predicted: 0.089
# Actual: 0.000, Predicted: 0.012
# Actual: 0.000, Predicted: -0.089
# Actual: 0.000, Predicted: 0.008
# Actual: 0.000, Predicted: 0.065
# Actual: 0.000, Predicted: 0.009
# Actual: 0.000, Predicted: 0.029
# Actual: 0.000, Predicted: -0.058
# Actual: 0.000, Predicted: -0.012
# Actual: 0.000, Predicted: -0.062
# Actual: 0.000, Predicted: -0.055
# Actual: 0.000, Predicted: 0.007
# Actual: 0.000, Predicted: -0.053
# Actual: 0.000, Predicted: -0.056
# Actual: 0.000, Predicted: -0.125
# Actual: 0.000, Predicted: -0.248
# Actual: 0.000, Predicted: -0.122
# Actual: 0.000, Predicted: -0.103
# Actual: 0.000, Predicted: -0.254
# Actual: 0.000, Predicted: -0.104
# Actual: 0.000, Predicted: 0.012
# Actual: 0.000, Predicted: -0.038
# Actual: 0.000, Predicted: 0.020
# Actual: 0.000, Predicted: 0.151
# Actual: 0.000, Predicted: 0.016
# Actual: 0.000, Predicted: 0.124
# Actual: 0.000, Predicted: 0.108
# Actual: 0.000, Predicted: -0.066
# Actual: 0.000, Predicted: 0.058
# Actual: 0.000, Predicted: -0.010
# Actual: 0.000, Predicted: 0.051
# Actual: 0.000, Predicted: -0.023
# Actual: 0.000, Predicted: -0.007
# Actual: 0.000, Predicted: 0.065
# Actual: 0.000, Predicted: 0.079
# Actual: 0.000, Predicted: 0.016
# Actual: 0.000, Predicted: -0.013
# Actual: 0.000, Predicted: -0.055
# Actual: 0.000, Predicted: -0.009
# Actual: 0.000, Predicted: 0.056
# Actual: 0.000, Predicted: 0.079
# Actual: 0.000, Predicted: 0.086
# Actual: 0.000, Predicted: 0.032
# Actual: 0.000, Predicted: 0.006
# Actual: 0.000, Predicted: 0.009
# Actual: 0.000, Predicted: 0.014
# Actual: 0.000, Predicted: 0.117
# Actual: 0.000, Predicted: -0.069
# Actual: 0.000, Predicted: -0.186
# Actual: 0.000, Predicted: -0.057
# Actual: 0.000, Predicted: 0.015
# Actual: 0.000, Predicted: -0.062
# Actual: 0.000, Predicted: 0.497
# Actual: 0.000, Predicted: 0.516
# Actual: 0.000, Predicted: 0.343
# Actual: 0.000, Predicted: 0.198
# Actual: 0.000, Predicted: 0.130
# Actual: 0.000, Predicted: 0.142
# Actual: 0.000, Predicted: -0.048
# Actual: 0.000, Predicted: -0.269
# Actual: 0.000, Predicted: -0.367
# Actual: 0.000, Predicted: -0.354
# Actual: 0.000, Predicted: -0.106
# Actual: 0.000, Predicted: -0.013
# Actual: 0.000, Predicted: 0.050
# Actual: 0.000, Predicted: -0.016
# Actual: 0.000, Predicted: -0.023
# Actual: 2.000, Predicted: -0.002
# Actual: 0.500, Predicted: -0.006
# Actual: 0.500, Predicted: 0.066
# Actual: 0.000, Predicted: 0.087
# Actual: 0.000, Predicted: 0.044
# Actual: 0.000, Predicted: 0.070
# Actual: 0.000, Predicted: 0.029
# Actual: 0.000, Predicted: -0.043
# Actual: 0.000, Predicted: 0.005
# Actual: 0.000, Predicted: 0.063
# Actual: 0.000, Predicted: 0.012
# Actual: 0.000, Predicted: -0.052
# Actual: 0.000, Predicted: 0.011
# Actual: 0.000, Predicted: 0.196
# Actual: 0.000, Predicted: 0.239
# Actual: 0.000, Predicted: 0.266
# Actual: 0.000, Predicted: 0.309
# Actual: 0.000, Predicted: 0.251
# Actual: 0.000, Predicted: 0.125
# Actual: 0.000, Predicted: 0.210
# Actual: 0.000, Predicted: 0.389
# Actual: 0.000, Predicted: -0.145
# Actual: 0.000, Predicted: 0.021
# Actual: 0.000, Predicted: -0.079
# Actual: 0.000, Predicted: -0.078
# Actual: 0.000, Predicted: -0.081
# Actual: 0.000, Predicted: 0.010
# Actual: 0.000, Predicted: 0.178
# Actual: 0.000, Predicted: 0.132
# Actual: 0.000, Predicted: -0.035
# Actual: 0.000, Predicted: -0.042
# Actual: 0.000, Predicted: -0.058
# Actual: 0.000, Predicted: -0.011
# Actual: 0.000, Predicted: -0.153
# Actual: 0.000, Predicted: 0.307
# Actual: 0.000, Predicted: 0.976
# Actual: 0.000, Predicted: 0.239
# Actual: 0.000, Predicted: -0.098
# Actual: 0.000, Predicted: 0.543
# Actual: 0.000, Predicted: -0.101
# Actual: 0.000, Predicted: -0.036
# Actual: 0.000, Predicted: -0.009
# Actual: 0.000, Predicted: -0.244
# Actual: 0.000, Predicted: -0.206
# Actual: 0.000, Predicted: -0.037
# Actual: 0.000, Predicted: -0.173
# Actual: 0.000, Predicted: -0.160
# Actual: 0.000, Predicted: 0.081
# Actual: 0.000, Predicted: 0.180
# Actual: 0.000, Predicted: 0.050
# Actual: 0.000, Predicted: 0.194
# Actual: 0.000, Predicted: 0.347
# Actual: 0.000, Predicted: 0.720
# Actual: 0.000, Predicted: 1.319
# Actual: 0.000, Predicted: 1.053
# Actual: 0.000, Predicted: 0.987
# Actual: 0.000, Predicted: 0.346
# Actual: 0.000, Predicted: 0.169
# Actual: 0.000, Predicted: 0.147
# Actual: 0.000, Predicted: 0.187
# Actual: 0.000, Predicted: 0.250
# Actual: 0.000, Predicted: 0.115
# Actual: 0.000, Predicted: 0.079
# Actual: 0.000, Predicted: 0.028
# Actual: 0.000, Predicted: 0.033
# Actual: 0.000, Predicted: 0.039
# Actual: 0.000, Predicted: -0.013
# Actual: 0.000, Predicted: 0.003
# Actual: 0.000, Predicted: -0.176
# Actual: 0.000, Predicted: -0.142
# Actual: 0.000, Predicted: -0.099
# Actual: 0.000, Predicted: -0.067
# Actual: 0.000, Predicted: -0.115
# Actual: 0.000, Predicted: 0.113
# Actual: 0.000, Predicted: 0.257
# Actual: 0.000, Predicted: 0.055
# Actual: 0.000, Predicted: -0.037
# Actual: 0.000, Predicted: 0.420
# Actual: 0.000, Predicted: 0.004
# Actual: 0.000, Predicted: -0.157
# Actual: 0.000, Predicted: -0.001
# Actual: 0.000, Predicted: 0.140
# Actual: 0.000, Predicted: -0.171
# Actual: 0.000, Predicted: -0.096
# Actual: 0.000, Predicted: 0.082
# Actual: 0.000, Predicted: 1.027
# Actual: 0.000, Predicted: 0.864
# Actual: 0.000, Predicted: 0.378
# Actual: 0.000, Predicted: -0.332
# Actual: 0.000, Predicted: -0.151
# Actual: 0.000, Predicted: 0.366
# Actual: 0.000, Predicted: -0.225
# Actual: 0.000, Predicted: -0.165
# Actual: 0.000, Predicted: 0.144
# Actual: 0.000, Predicted: -0.455
# Actual: 0.000, Predicted: 0.042
# Actual: 0.000, Predicted: 0.059
# Actual: 0.000, Predicted: 0.032
# Actual: 0.000, Predicted: 0.060
# Actual: 0.000, Predicted: 0.008
# Actual: 0.000, Predicted: -0.028
# Actual: 0.000, Predicted: 0.014
# Actual: 0.000, Predicted: 0.004
# Actual: 0.000, Predicted: -0.010
# Actual: 0.000, Predicted: 0.112
# Actual: 0.000, Predicted: -0.871
# Actual: 0.000, Predicted: 0.045
# Actual: 0.000, Predicted: -0.110
# Actual: 0.000, Predicted: -0.052
# Actual: 0.000, Predicted: 0.184
# Actual: 0.000, Predicted: 0.082
# Actual: 0.000, Predicted: -0.356
# Actual: 0.000, Predicted: -0.349
# Actual: 0.000, Predicted: 0.280
# Actual: 0.000, Predicted: -0.536
# Actual: 0.000, Predicted: -0.344
# Actual: 0.000, Predicted: -0.727
# Actual: 0.000, Predicted: -0.383
# Actual: 0.000, Predicted: -0.410
# Actual: 0.000, Predicted: -0.079
# Actual: 0.000, Predicted: -0.156
# Actual: 0.000, Predicted: -0.041
# Actual: 0.000, Predicted: -0.127
# Actual: 0.000, Predicted: -0.181
# Actual: 0.000, Predicted: -0.068
# Actual: 0.000, Predicted: -0.121
# Actual: 0.000, Predicted: -0.628
# Actual: 0.000, Predicted: -0.093
# Actual: 0.000, Predicted: -0.088
# Actual: 0.000, Predicted: -0.209
# Actual: 0.000, Predicted: 0.053
# Actual: 0.000, Predicted: -0.145
# Actual: 0.000, Predicted: -0.986
# Actual: 0.000, Predicted: -0.343
# Actual: 0.000, Predicted: 0.959
# Actual: 0.000, Predicted: 0.865
# Actual: 0.000, Predicted: -0.388
# Actual: 0.000, Predicted: -0.449
# Actual: 0.000, Predicted: -0.202
# Actual: 0.000, Predicted: -0.015
# Actual: 0.000, Predicted: 0.235
# Actual: 0.000, Predicted: 0.077
# Actual: 0.000, Predicted: 0.042
# Actual: 0.000, Predicted: 0.166
# Actual: 0.000, Predicted: 0.013
# Actual: 0.000, Predicted: 0.059
# Actual: 0.000, Predicted: -0.053
# Actual: 0.000, Predicted: -0.047
# Actual: 0.000, Predicted: -0.081
# Actual: 0.000, Predicted: -0.204
# Actual: 0.000, Predicted: -0.202
# Actual: 0.000, Predicted: -0.112
# Actual: 0.000, Predicted: -0.239
# Actual: 0.000, Predicted: -0.053
# Actual: 0.000, Predicted: 0.285
# Actual: 0.000, Predicted: 2.247
# Actual: 0.000, Predicted: 0.897
# Actual: 0.000, Predicted: 0.632
# Actual: 0.000, Predicted: 0.074
# Actual: 0.000, Predicted: 0.018
# Actual: 0.000, Predicted: 0.096
# Actual: 0.000, Predicted: 0.726
# Actual: 0.000, Predicted: 0.585
# Actual: 0.000, Predicted: -0.041
# Actual: 0.000, Predicted: -0.159
# Actual: 0.000, Predicted: -0.195
# Actual: 0.000, Predicted: -0.137
# Actual: 0.000, Predicted: 0.031
# Actual: 0.000, Predicted: 0.035
# Actual: 0.000, Predicted: -0.020
# Actual: 0.000, Predicted: -0.011
# Actual: 0.000, Predicted: -0.065
# Actual: 0.000, Predicted: -0.030
# Actual: 0.000, Predicted: -0.015
# Actual: 0.000, Predicted: -0.066
# Actual: 0.000, Predicted: -0.042
# Actual: 0.000, Predicted: 0.123
# Actual: 0.000, Predicted: 1.034
# Actual: 0.000, Predicted: 0.632
# Actual: 3.500, Predicted: 0.301
# Actual: 0.000, Predicted: 0.116
# Actual: 0.000, Predicted: 0.033
# Actual: 1.500, Predicted: 0.172
# Actual: 0.500, Predicted: 0.180
# Actual: 0.000, Predicted: 0.199
# Actual: 1.500, Predicted: 0.094
# Actual: 0.000, Predicted: 0.022
# Actual: 0.000, Predicted: -0.152
# Actual: 0.000, Predicted: -0.078
# Actual: 0.000, Predicted: 0.087
# Actual: 0.000, Predicted: 0.052
# Actual: 0.000, Predicted: -0.066
# Actual: 0.000, Predicted: 0.040
# Actual: 0.000, Predicted: -0.247
# Actual: 0.000, Predicted: 0.274
# Actual: 0.000, Predicted: 0.117
# Actual: 0.000, Predicted: 0.018
# Actual: 0.000, Predicted: 0.066
# Actual: 0.000, Predicted: 0.127
# Actual: 0.000, Predicted: 0.167
# Actual: 0.000, Predicted: 0.148
# Actual: 0.000, Predicted: 0.120
# Actual: 0.000, Predicted: 0.132
# Actual: 0.000, Predicted: 0.119
# Actual: 0.000, Predicted: 0.091
# Actual: 0.000, Predicted: 0.109
# Actual: 0.000, Predicted: 0.101
# Actual: 0.000, Predicted: 0.076
# Actual: 0.000, Predicted: 0.037
# Actual: 0.000, Predicted: 0.024
# Actual: 0.000, Predicted: 0.081
# Actual: 0.000, Predicted: 0.060
# Actual: 0.000, Predicted: 0.096
# Actual: 0.000, Predicted: 0.128
# Actual: 0.000, Predicted: 0.167
# Actual: 0.000, Predicted: 0.186
# Actual: 0.000, Predicted: 0.121
# Actual: 0.000, Predicted: 0.339
# Actual: 0.000, Predicted: 0.069
# Actual: 0.000, Predicted: 0.159
# Actual: 0.000, Predicted: 0.091
# Actual: 0.000, Predicted: 0.065
# Actual: 0.000, Predicted: 0.041
# Actual: 0.000, Predicted: 0.030
# Actual: 0.000, Predicted: 0.025
# Actual: 0.000, Predicted: 0.003
# Actual: 0.000, Predicted: 0.004
# Actual: 0.000, Predicted: 0.025
# Actual: 0.000, Predicted: 0.007
# Actual: 0.000, Predicted: 0.030
# Actual: 0.000, Predicted: 0.097
# Actual: 0.000, Predicted: 0.100
# Actual: 0.000, Predicted: 0.020
# Actual: 0.000, Predicted: -0.126
# Actual: 0.000, Predicted: -0.064
# Actual: 0.000, Predicted: -0.007
# Actual: 0.000, Predicted: 0.018
# Actual: 0.000, Predicted: 0.099
# Actual: 0.000, Predicted: 0.047
# Actual: 0.000, Predicted: -0.035
# Actual: 0.000, Predicted: 0.058
# Actual: 0.000, Predicted: 0.025
# Actual: 0.000, Predicted: 0.141
# Actual: 0.000, Predicted: -0.022
# Actual: 0.000, Predicted: 0.080
# Actual: 0.000, Predicted: 0.062
# Actual: 0.000, Predicted: 0.067
# Actual: 0.000, Predicted: 0.243
# Actual: 0.000, Predicted: 0.665
# Actual: 0.000, Predicted: 0.171
# Actual: 0.000, Predicted: 0.076
# Actual: 0.000, Predicted: 0.805
# Actual: 0.000, Predicted: 0.395
# Actual: 0.000, Predicted: 0.195
# Actual: 0.000, Predicted: 0.235
# Actual: 0.000, Predicted: 0.022
# Actual: 0.000, Predicted: -0.061
# Actual: 0.000, Predicted: -0.112
# Actual: 0.000, Predicted: -0.202
# Actual: 0.000, Predicted: -0.328
# Actual: 0.000, Predicted: -0.166
# Actual: 0.000, Predicted: -0.164
# Actual: 0.000, Predicted: -0.214
# Actual: 0.000, Predicted: -0.073
# Actual: 0.000, Predicted: -0.008
# Actual: 0.000, Predicted: -0.003
# Actual: 0.000, Predicted: 0.070
# Actual: 0.000, Predicted: 0.008
